# %%
import glob
import os
import time
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import tensorflow as tf
import argparse
import sys
import time

# %% [markdown]
# ### Code Snippets from TensorFlow for Poets instructions:
# (https://codelabs.developers.google.com/codelabs/tensorflow-for-poets-2).

# %%
def load_graph(model_file):
    graph = tf.Graph()
    graph_def = tf.GraphDef()

    with open(model_file, "rb") as f:
        graph_def.ParseFromString(f.read())
    with graph.as_default():
        tf.import_graph_def(graph_def)

    return graph

# %%
def read_tensor_from_image_file(file_name, input_height=299, input_width=299, input_mean=0, input_std=255):
    input_name = "file_reader"
    output_name = "normalized"
    file_reader = tf.read_file(file_name, input_name)
    if file_name.endswith(".png"):
        image_reader = tf.image.decode_png(file_reader, channels = 3,
                                       name='png_reader')
    elif file_name.endswith(".gif"):
        image_reader = tf.squeeze(tf.image.decode_gif(file_reader,
                                                  name='gif_reader'))
    elif file_name.endswith(".bmp"):
        image_reader = tf.image.decode_bmp(file_reader, name='bmp_reader')
    else:
        image_reader = tf.image.decode_jpeg(file_reader, channels = 3,
                                        name='jpeg_reader')
    float_caster = tf.cast(image_reader, tf.float32)
    dims_expander = tf.expand_dims(float_caster, 0);
    resized = tf.image.resize_bilinear(dims_expander, [input_height, input_width])
    normalized = tf.divide(tf.subtract(resized, [input_mean]), [input_std])
    sess = tf.Session()
    result = sess.run(normalized)

    return result

# %%
def load_labels(label_file):
    label = []
    proto_as_ascii_lines = tf.gfile.GFile(label_file).readlines()
    for l in proto_as_ascii_lines:
        label.append(l.rstrip())
    return label

# %% [markdown]
# ### Process each image through the trained model to predict a classification.
#
# This cell will first creat a new dictionary object to save classifications to. Next it creates a loop to iterate over each filename in the subsquent 'test_files' folder (change this part of the path to the eventual correct place).
#
# Next it loads the graph.pb file we built while training the model with inception V3.
#
# We make a prediction on the file's class and adds the count to the dictionary first created.

# %%
test_dict = {}

# %%
labels = load_labels("tf_files/retrained_labels.txt")

# %%
for im in glob.glob('tf_files/test_files2/*/*'):
    test_dict[im.split('/')[-2]]={labels[i]:0 for i in range(len(labels))}

# %%
image_classification_df_1 = pd.DataFrame.from_dict(test_dict, orient='index')

# %% [markdown]
# Trial with tf.session set outside of for loop:

# %%
graph = load_graph("tf_files/retrained_graph.pb")
labels = load_labels("tf_files/retrained_labels.txt")
input_height = 224
input_width = 224
input_mean = 128
input_std = 128
input_layer = "input"
output_layer = "final_result"
input_name = "import/" + input_layer
output_name = "import/" + output_layer
sess = tf.Session(graph=graph)
input_operation = graph.get_operation_by_name(input_name);
output_operation = graph.get_operation_by_name(output_name);
for im in glob.glob('tf_files/test_files2/*/*'):
    start = time.time()
#     file_name = "tf_files/test_files2/" + im.split('/')[-2]+'/'+ im.split('/')[-1] 
    try:
        t = read_tensor_from_image_file(im,
                                    input_height=input_height,
                                    input_width=input_width,
                                    input_mean=input_mean,
                                    input_std=input_std)
        
        results = sess.run(output_operation.outputs[0],
                                  {input_operation.outputs[0]: t})
        results = np.squeeze(results)
        
            
        i = int(results.argsort()[-1:][::-1])
        
        image_classification_df_1.loc[im.split('/')[-2], labels[i]]+=1
        
    except:
        pass
    end=time.time()
    print('Evaluation time (1-image): {:.3f}s'.format(end-start))
# Out:
# Evaluation time (1-image): 0.796s
# Evaluation time (1-image): 0.296s
# Evaluation time (1-image): 0.471s
# Evaluation time (1-image): 0.308s
# Evaluation time (1-image): 0.290s
# Evaluation time (1-image): 0.297s
# Evaluation time (1-image): 0.430s
# Evaluation time (1-image): 0.321s
# Evaluation time (1-image): 0.296s
# Evaluation time (1-image): 0.313s
# Evaluation time (1-image): 0.296s
# Evaluation time (1-image): 0.288s
# Evaluation time (1-image): 0.296s
# Evaluation time (1-image): 0.290s
# Evaluation time (1-image): 0.300s
# Evaluation time (1-image): 0.333s
# Evaluation time (1-image): 0.459s
# Evaluation time (1-image): 0.305s
# Evaluation time (1-image): 0.296s
# Evaluation time (1-image): 0.319s
# Evaluation time (1-image): 0.423s
# Evaluation time (1-image): 0.378s
# Evaluation time (1-image): 0.299s
# Evaluation time (1-image): 0.314s
# Evaluation time (1-image): 0.307s
# Evaluation time (1-image): 0.292s
# Evaluation time (1-image): 0.295s
# Evaluation time (1-image): 0.293s
# Evaluation time (1-image): 0.299s
# Evaluation time (1-image): 0.299s
# Evaluation time (1-image): 0.304s
# Evaluation time (1-image): 0.299s
# Evaluation time (1-image): 0.390s
# Evaluation time (1-image): 0.315s
# Evaluation time (1-image): 0.396s
# Evaluation time (1-image): 0.311s
# Evaluation time (1-image): 0.310s
# Evaluation time (1-image): 0.303s
# Evaluation time (1-image): 0.448s
# Evaluation time (1-image): 0.310s
# Evaluation time (1-image): 0.331s
# Evaluation time (1-image): 0.315s
# Evaluation time (1-image): 0.320s
# Evaluation time (1-image): 0.320s
# Evaluation time (1-image): 0.321s
# Evaluation time (1-image): 0.431s
# Evaluation time (1-image): 0.497s
# Evaluation time (1-image): 0.482s
# Evaluation time (1-image): 0.311s
# Evaluation time (1-image): 0.326s
# Evaluation time (1-image): 0.317s
# Evaluation time (1-image): 0.325s
# Evaluation time (1-image): 0.313s
# Evaluation time (1-image): 0.313s
# Evaluation time (1-image): 0.312s
# Evaluation time (1-image): 0.312s
# Evaluation time (1-image): 0.314s
# Evaluation time (1-image): 0.312s
# Evaluation time (1-image): 0.325s
# Evaluation time (1-image): 0.330s
# Evaluation time (1-image): 0.314s
# Evaluation time (1-image): 0.317s
# Evaluation time (1-image): 0.316s
# Evaluation time (1-image): 0.339s
# Evaluation time (1-image): 0.320s
# Evaluation time (1-image): 0.328s
# Evaluation time (1-image): 0.312s
# Evaluation time (1-image): 0.313s
# Evaluation time (1-image): 0.311s
# Evaluation time (1-image): 0.313s
# Evaluation time (1-image): 0.314s
# Evaluation time (1-image): 0.319s
# Evaluation time (1-image): 0.324s
# Evaluation time (1-image): 0.327s
# Evaluation time (1-image): 0.335s
# Evaluation time (1-image): 0.322s
# Evaluation time (1-image): 0.346s
# Evaluation time (1-image): 0.336s
# Evaluation time (1-image): 0.327s
# Evaluation time (1-image): 0.340s
# Evaluation time (1-image): 0.462s
# Evaluation time (1-image): 0.342s
# Evaluation time (1-image): 0.326s
# Evaluation time (1-image): 0.379s
# Evaluation time (1-image): 0.350s
# Evaluation time (1-image): 0.319s
# Evaluation time (1-image): 0.417s
# Evaluation time (1-image): 0.443s
# Evaluation time (1-image): 0.414s
# Evaluation time (1-image): 0.319s
# Evaluation time (1-image): 0.403s
# Evaluation time (1-image): 0.419s
# Evaluation time (1-image): 0.378s
# Evaluation time (1-image): 0.343s
# Evaluation time (1-image): 0.347s
# Evaluation time (1-image): 0.354s
# Evaluation time (1-image): 0.342s
# Evaluation time (1-image): 0.335s
# Evaluation time (1-image): 0.341s
# Evaluation time (1-image): 0.326s
# Evaluation time (1-image): 0.326s
# Evaluation time (1-image): 0.338s
# Evaluation time (1-image): 0.360s
# Evaluation time (1-image): 0.362s
# Evaluation time (1-image): 0.342s
# Evaluation time (1-image): 0.416s
# Evaluation time (1-image): 0.374s
# Evaluation time (1-image): 0.339s
# Evaluation time (1-image): 0.346s
# Evaluation time (1-image): 0.365s
# Evaluation time (1-image): 0.324s
# Evaluation time (1-image): 0.326s
# Evaluation time (1-image): 0.378s
# Evaluation time (1-image): 0.380s
# Evaluation time (1-image): 0.351s
# Evaluation time (1-image): 0.332s
# Evaluation time (1-image): 0.365s
# Evaluation time (1-image): 0.352s
# Evaluation time (1-image): 0.420s
# Evaluation time (1-image): 0.335s
# Evaluation time (1-image): 0.395s
# Evaluation time (1-image): 0.363s
# Evaluation time (1-image): 0.351s
# Evaluation time (1-image): 0.336s
# Evaluation time (1-image): 0.331s
# Evaluation time (1-image): 0.389s
# Evaluation time (1-image): 0.430s
# Evaluation time (1-image): 0.379s
# Evaluation time (1-image): 0.358s
# Evaluation time (1-image): 0.342s
# Evaluation time (1-image): 0.341s
# Evaluation time (1-image): 0.350s
# Evaluation time (1-image): 0.340s
# Evaluation time (1-image): 0.352s
# Evaluation time (1-image): 0.365s
# Evaluation time (1-image): 0.343s
# Evaluation time (1-image): 0.347s
# Evaluation time (1-image): 0.359s
# Evaluation time (1-image): 0.346s
# Evaluation time (1-image): 0.347s
# Evaluation time (1-image): 0.354s
# Evaluation time (1-image): 0.341s
# Evaluation time (1-image): 0.344s
# Evaluation time (1-image): 0.337s
# Evaluation time (1-image): 0.346s
# Evaluation time (1-image): 0.336s
# Evaluation time (1-image): 0.349s
# Evaluation time (1-image): 0.387s
# Evaluation time (1-image): 0.385s
# Evaluation time (1-image): 0.352s
# Evaluation time (1-image): 0.352s
# Evaluation time (1-image): 0.371s
# Evaluation time (1-image): 0.359s
# Evaluation time (1-image): 0.358s
# Evaluation time (1-image): 0.397s
# Evaluation time (1-image): 0.375s
# Evaluation time (1-image): 0.357s
# Evaluation time (1-image): 0.366s
# Evaluation time (1-image): 0.358s
# Evaluation time (1-image): 0.366s
# Evaluation time (1-image): 0.365s
# Evaluation time (1-image): 0.372s
# Evaluation time (1-image): 0.367s
# Evaluation time (1-image): 0.368s
# Evaluation time (1-image): 0.369s
# Evaluation time (1-image): 0.363s
# Evaluation time (1-image): 0.366s
# Evaluation time (1-image): 0.356s
# Evaluation time (1-image): 0.354s
# Evaluation time (1-image): 0.398s
# Evaluation time (1-image): 0.362s
# Evaluation time (1-image): 0.357s
# Evaluation time (1-image): 0.354s
# Evaluation time (1-image): 0.370s
# Evaluation time (1-image): 0.370s
# Evaluation time (1-image): 0.365s
# Evaluation time (1-image): 0.393s
# Evaluation time (1-image): 0.365s

# %% [markdown]
# As a matter of creating a checkpoint in large routines, I save this file to a .csv. Just in case the following proceses need to be run again, I can start here by simply loading the csv, rather than reprocessing the files.

# %%
image_classification_df.to_csv('image_classification_df.csv')

# %% [markdown]
# ### Cosine Similarty
#
# Finally we create a cosine similarity among each user given their photos.

# %% [markdown]
# Due to computational time, I was forced to break up each classification into bins of 2000. The following cells append each group of 2000 rows into a single dataframe.

# %%
df_1 = pd.read_csv('../2000/image_csv/image_classification_df_1.csv', index_col=[0])
df_2 = pd.read_csv('../2000/image_csv/image_classification_df_2.csv',index_col=[0])
df_3 = pd.read_csv('../2000/image_csv/image_classification_df_3.csv',index_col=[0])
df_4 = pd.read_csv('../2000/image_csv/image_classification_df_4.csv',index_col=[0])
df_5 = pd.read_csv('../2000/image_csv/image_classification_df_5.csv',index_col=[0])
df_6 = pd.read_csv('../2000/image_csv/image_classification_df_6.csv',index_col=[0])
df_7 = pd.read_csv('../2000/image_csv/image_classification_df_7.csv',index_col=[0])
df_8 = pd.read_csv('../2000/image_csv/image_classification_df_8.csv',index_col=[0])
df_9 = pd.read_csv('../2000/image_csv/image_classification_df_9.csv',index_col=[0])
df_10 = pd.read_csv('../2000/image_csv/image_classification_df_10.csv',index_col=[0])

# %%
df_11 = pd.read_csv('../2000/image_csv/image_classification_df_11.csv',index_col=[0])
df_12= pd.read_csv('../2000/image_csv/image_classification_df_12.csv',index_col=[0])
df_13= pd.read_csv('../2000/image_csv/image_classification_df_13.csv',index_col=[0])
df_14 = pd.read_csv('../2000/image_csv/image_classification_df_14.csv',index_col=[0])
df_15 = pd.read_csv('../2000/image_csv/image_classification_df_15.csv',index_col=[0])
df_16 = pd.read_csv('../2000/image_csv/image_classification_df_16.csv',index_col=[0])
df_17 = pd.read_csv('../2000/image_csv/image_classification_df_17.csv',index_col=[0])
df_18 = pd.read_csv('../2000/image_csv/image_classification_df_18.csv',index_col=[0])
df_19 = pd.read_csv('../2000/image_csv/image_classification_df_19.csv',index_col=[0])
df_20 = pd.read_csv('../2000/image_csv/image_classification_df_20.csv',index_col=[0])

# %%
df_list = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20]
df_final = pd.DataFrame()
for i in df_list:
    df_final = df_final.append(i)

# %%
df_final.describe()
# Out:
#             beauty        group        jeans          abs  architecture  \
# count  1948.000000  1948.000000  1948.000000  1948.000000   1948.000000
# mean      0.433265     0.583676     0.518480     0.115503      0.850103
# std       1.594856     1.056533     1.010559     0.522239      1.778464
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       0.000000     0.000000     0.000000     0.000000      0.000000
# 50%       0.000000     0.000000     0.000000     0.000000      0.000000
# 75%       0.000000     1.000000     1.000000     0.000000      1.000000
# max      20.000000    10.000000    11.000000    11.000000     15.000000
#
#               baby          bag       bikini          car        close  ...  \
# count  1948.000000  1948.000000  1948.000000  1948.000000  1948.000000  ...
# mean      0.942505     0.141170     0.682752     0.185832     0.800821  ...
# std       1.600520     0.451089     1.466969     0.733220     1.558435  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%       1.000000     0.000000     1.000000     0.000000     1.000000  ...
# max      20.000000     6.000000    15.000000    14.000000    19.000000  ...
#
#           menswear        ocean       outfit          pet        plant  \
# count  1948.000000  1948.000000  1948.000000  1948.000000  1948.000000
# mean      0.948665     0.561088     1.856776     0.531828     0.532341
# std       1.854888     1.424658     2.479401     1.947570     1.047158
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     1.000000     0.000000     0.000000
# 75%       1.000000     0.000000     3.000000     0.000000     1.000000
# max      17.000000    12.000000    16.000000    20.000000    11.000000
#
#             selfie        shoes          sun         text      wedding
# count  1948.000000  1948.000000  1948.000000  1948.000000  1948.000000
# mean      0.501027     0.191992     0.079055     1.255647     0.219713
# std       1.074282     0.517885     0.361064     2.695341     0.647370
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     0.000000     1.000000     0.000000
# max      17.000000     5.000000     6.000000    20.000000     9.000000
#
# [8 rows x 31 columns]

# %%
cos_sim_images = pd.DataFrame(cosine_similarity(df_final, dense_output=False), index=df_final.index, columns=df_final.index)

# %%
cos_sim_images.head()
# Out:
#           5592      56040     56085     5610      5620      56207     56221  \
# 5592   1.000000  0.553912  0.370370  0.202113  0.368932  0.060193  0.398962
# 56040  0.553912  1.000000  0.287213  0.134343  0.506024  0.200049  0.441980
# 56085  0.370370  0.287213  1.000000  0.754555  0.175682  0.421350  0.356966
# 5610   0.202113  0.134343  0.754555  1.000000  0.000000  0.394171  0.213896
# 5620   0.368932  0.506024  0.175682  0.000000  1.000000  0.114208  0.478091
#
#           5627      56304     5658   ...     67893     67919     68023  \
# 5592   0.132099  0.596913  0.255155  ...  0.226805  0.153522  0.411302
# 56040  0.125436  0.475000  0.226134  ...  0.276385  0.048593  0.403075
# 56085  0.207584  0.277438  0.170103  ...  0.181444  0.690849  0.110735
# 5610   0.192232  0.012234  0.000000  ...  0.330049  0.941503  0.126613
# 5620   0.107417  0.271177  0.677772  ...  0.193649  0.010403  0.390195
#
#           68071     6816      68289     68379     68395     68433     6846
# 5592   0.160817  0.150616  0.600099  0.309142  0.161416  0.300557  0.174603
# 56040  0.257337  0.166856  0.423057  0.402911  0.227590  0.399556  0.070338
# 56085  0.178685  0.365782  0.272772  0.181848  0.278809  0.525974  0.674603
# 5610   0.247024  0.250490  0.052926  0.066157  0.053385  0.754470  0.883523
# 5620   0.203419  0.020412  0.207020  0.327781  0.167054  0.085540  0.037646
#
# [5 rows x 1948 columns]

# %% [markdown]
# Finally, I save this cosine similarity file to a csv, to be joined with NLP data and explicit user input to make a final prediction on similarity.

# %%
cos_sim_images.to_csv('../2000/2000_cos_sim_images.csv')
